# %% [markdown]
# <a href="https://colab.research.google.com/github/morphingdesign/tfExplore/blob/master/TF_Process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Step 1: Read in Data

# %%
sns.set_style('whitegrid')

# %%
df = pd.read_csv('sample_data/data/fake_reg.csv')
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %% [markdown]
# # Step 2: EDA (Exploratory Data Analysis) & Feature Engineering

# %%
sns.pairplot(df)

# %% [markdown]
# # Step 3: Train/Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['feature1', 'feature2']].values

# %%
y = df['price'].values

# %%
X
# Out:
# array([[ 999.78755752,  999.7660962 ],
#        [ 998.86161491, 1001.04240315],
#        [1000.07026691,  998.84401463],
#        ...,
#        [1001.45164617,  998.84760554],
#        [1000.77102275,  998.56285086],
#        [ 999.2322436 , 1001.45140713]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (700, 2)

# %%
X_test.shape
# Out:
# (300, 2)

# %% [markdown]
# # Step 4: Normalize & Scale Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = scaler.transform(X_train)

# %%
X_train.min()
# Out:
# 0.0

# %%
X_test = scaler.transform(X_test)

# %%
X_test.min()
# Out:
# -0.014108392024581917
